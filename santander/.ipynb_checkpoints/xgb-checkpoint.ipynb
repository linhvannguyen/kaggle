# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split, cross_val_score, StratifiedKFold
from sklearn import linear_model, metrics, preprocessing
from sklearn.feature_selection import RFE,SelectPercentile,f_classif,chi2
from sklearn.metrics import roc_auc_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier 
from sklearn.feature_selection import SelectFromModel
import xgboost as xgb

# %% [markdown]
# ### Load data

# %%
df_train = pd.read_csv('./data/train.csv')
df_test = pd.read_csv('./data/test.csv')

skf_cv = StratifiedKFold(df_train['TARGET'], n_folds=6, shuffle=True, random_state=None) # split target equally
def score_model(model,X,t):
    #return cross_val_score(model, X, t, cv=6, scoring="roc_auc",n_jobs=3)
    return cross_val_score(model, X, t, cv=skf_cv, scoring="roc_auc",n_jobs=4)

# %% [markdown]
# ### Remove constant columns

# %%
remove = []
for col in df_train.columns:
    if df_train[col].std() == 0:
        remove.append(col)

df_train.drop(remove, axis=1, inplace=True)
df_test.drop(remove, axis=1, inplace=True)

# %% [markdown]
# ### Remove duplicated columns

# %%
remove = []
c = df_train.columns
for i in range(len(c)-1):
    v = df_train[c[i]].values
    for j in range(i+1,len(c)):
        if np.array_equal(v,df_train[c[j]].values):
            remove.append(c[j])

df_train.drop(remove, axis=1, inplace=True)
df_test.drop(remove, axis=1, inplace=True)

# %% [markdown]
# ### Other cleaning

# %%
# Replace -999999 in var3 column with most common value 2 
df_train = df_train.replace(-999999,2)
df_test = df_test.replace(-999999,2)

# %% [markdown]
# ### Feature selection

# %%
Xdf_tr = df_train.drop('TARGET', 1)
tdf_tr = df_train.TARGET

from sklearn.preprocessing import Binarizer, scale

p = 50 # percentage of selected features

X_bin = Binarizer().fit_transform(scale(Xdf_tr))
selectChi2 = SelectPercentile(chi2, percentile=p).fit(X_bin, tdf_tr)
selectF_classif = SelectPercentile(f_classif, percentile=p).fit(Xdf_tr, tdf_tr)

chi2_selected = selectChi2.get_support()
chi2_selected_features = [ f for i,f in enumerate(Xdf_tr.columns) if chi2_selected[i]]

f_classif_selected = selectF_classif.get_support()
f_classif_selected_features = [ f for i,f in enumerate(Xdf_tr.columns) if f_classif_selected[i]]


selected = chi2_selected | f_classif_selected
print('Chi2 & F_classif selected {} features'.format(selected.sum()))
features = [ f for f,s in zip(Xdf_tr.columns, selected) if s]

print('List of features:{}'.format(features))
Xdf=df_train[features]
# Out:
# Chi2 & F_classif selected 173 features
# List of features:['var3', 'var15', 'imp_op_var39_comer_ult1', 'imp_op_var40_efect_ult1', 'imp_op_var40_efect_ult3', 'imp_op_var41_comer_ult1', 'imp_op_var41_efect_ult1', 'imp_op_var41_efect_ult3', 'imp_op_var41_ult1', 'imp_op_var39_efect_ult1', 'imp_op_var39_efect_ult3', 'imp_op_var39_ult1', 'imp_sal_var16_ult1', 'ind_var1', 'ind_var5_0', 'ind_var5', 'ind_var8_0', 'ind_var8', 'ind_var12_0', 'ind_var12', 'ind_var13_0', 'ind_var13_corto_0', 'ind_var13_corto', 'ind_var13_largo_0', 'ind_var13_largo', 'ind_var13', 'ind_var14_0', 'ind_var14', 'ind_var17_0', 'ind_var19', 'ind_var20_0', 'ind_var20', 'ind_var24_0', 'ind_var24', 'ind_var25_cte', 'ind_var26_0', 'ind_var26_cte', 'ind_var25_0', 'ind_var30_0', 'ind_var30', 'ind_var31_0', 'ind_var31', 'ind_var33_0', 'ind_var33', 'ind_var39_0', 'ind_var40', 'ind_var41_0', 'ind_var44_0', 'num_var1', 'num_var4', 'num_var5_0', 'num_var5', 'num_var8_0', 'num_var8', 'num_var12_0', 'num_var12', 'num_var13_0', 'num_var13_corto_0', 'num_var13_corto', 'num_var13_largo_0', 'num_var13_largo', 'num_var13', 'num_var14_0', 'num_var14', 'num_var20_0', 'num_var20', 'num_var24_0', 'num_var24', 'num_var26_0', 'num_var25_0', 'num_op_var41_hace2', 'num_op_var41_ult1', 'num_op_var41_ult3', 'num_op_var39_hace2', 'num_op_var39_ult1', 'num_op_var39_ult3', 'num_var30_0', 'num_var30', 'num_var31_0', 'num_var31', 'num_var33_0', 'num_var35', 'num_var39_0', 'num_var40', 'num_var41_0', 'num_var42_0', 'num_var42', 'num_var44_0', 'saldo_var1', 'saldo_var5', 'saldo_var12', 'saldo_var13_corto', 'saldo_var13_largo', 'saldo_var13', 'saldo_var14', 'saldo_var20', 'saldo_var24', 'saldo_var26', 'saldo_var25', 'saldo_var30', 'saldo_var31', 'saldo_var40', 'saldo_var42', 'var36', 'delta_imp_aport_var13_1y3', 'delta_num_aport_var13_1y3', 'imp_aport_var13_hace3', 'imp_aport_var13_ult1', 'imp_reemb_var17_ult1', 'imp_var43_emit_ult1', 'imp_trans_var37_ult1', 'ind_var10_ult1', 'ind_var10cte_ult1', 'ind_var9_cte_ult1', 'ind_var9_ult1', 'ind_var43_emit_ult1', 'ind_var43_recib_ult1', 'num_aport_var13_hace3', 'num_aport_var13_ult1', 'num_ent_var16_ult1', 'num_var22_hace2', 'num_var22_ult1', 'num_var22_ult3', 'num_med_var22_ult3', 'num_med_var45_ult3', 'num_meses_var5_ult3', 'num_meses_var8_ult3', 'num_meses_var12_ult3', 'num_meses_var13_corto_ult3', 'num_meses_var13_largo_ult3', 'num_meses_var17_ult3', 'num_meses_var39_vig_ult3', 'num_meses_var44_ult3', 'num_op_var39_comer_ult1', 'num_op_var40_efect_ult1', 'num_op_var40_efect_ult3', 'num_op_var41_comer_ult1', 'num_op_var41_efect_ult1', 'num_op_var41_efect_ult3', 'num_op_var39_efect_ult1', 'num_op_var39_efect_ult3', 'num_reemb_var17_ult1', 'num_sal_var16_ult1', 'num_var43_emit_ult1', 'num_var43_recib_ult1', 'num_trasp_var11_ult1', 'num_var45_hace2', 'num_var45_hace3', 'num_var45_ult1', 'num_var45_ult3', 'saldo_medio_var5_hace2', 'saldo_medio_var5_hace3', 'saldo_medio_var5_ult1', 'saldo_medio_var5_ult3', 'saldo_medio_var8_hace2', 'saldo_medio_var8_hace3', 'saldo_medio_var8_ult1', 'saldo_medio_var8_ult3', 'saldo_medio_var12_hace2', 'saldo_medio_var12_hace3', 'saldo_medio_var12_ult1', 'saldo_medio_var12_ult3', 'saldo_medio_var13_corto_hace2', 'saldo_medio_var13_corto_hace3', 'saldo_medio_var13_corto_ult1', 'saldo_medio_var13_corto_ult3', 'saldo_medio_var13_largo_hace2', 'saldo_medio_var13_largo_hace3', 'saldo_medio_var13_largo_ult1', 'saldo_medio_var13_largo_ult3', 'saldo_medio_var17_hace2', 'saldo_medio_var44_hace2', 'var38']
# /home/nguyen/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.py:167: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "

# %% [markdown]
# ### Extract training data

# %%
# classifier
# http://xgboost.readthedocs.org/en/latest/parameter.html
# http://xgboost.readthedocs.org/en/latest/param_tuning.html
clf = xgb.XGBClassifier(
      objective= 'binary:logistic',    
      learning_rate=0.0175, 
      n_estimators=500,
      max_depth=8,
      subsample=0.9,
      colsample_bytree=0.87,
      nthread=4,
      silent = 1,
      seed=8
)
# best observed: learning_rate=0.0175, n_estimators=400,max_depth=8,subsample=0.9,colsample_bytree=0.87,  seed=8

X_tr = Xdf.as_matrix()
t_tr = df_train['TARGET'].as_matrix()

cv_scores={}
cv_scores['XGB']=score_model(clf, X_tr,t_tr)
print cv_scores
# Out:
# {'XGB': array([ 0.84632642,  0.84938658,  0.83402289,  0.8229484 ,  0.84665998,
#         0.8328258 ])}

# %%
# Split up the data for early stopping
X_fit, X_eval, t_fit, t_eval = train_test_split(X_tr, t_tr, test_size=0.25, random_state=42)

clf.fit(X_tr, t_tr, early_stopping_rounds=50, eval_metric="auc", eval_set=[(X_eval, t_eval)])
# Out:
# Will train until validation_0 error hasn't decreased in 50 rounds.
# [0]	validation_0-auc:0.722941
# [1]	validation_0-auc:0.779546
# [2]	validation_0-auc:0.802952
# [3]	validation_0-auc:0.807800
# [4]	validation_0-auc:0.810315
# [5]	validation_0-auc:0.812878
# [6]	validation_0-auc:0.808239
# [7]	validation_0-auc:0.805520
# [8]	validation_0-auc:0.807389
# [9]	validation_0-auc:0.800781
# [10]	validation_0-auc:0.805410
# [11]	validation_0-auc:0.804760
# [12]	validation_0-auc:0.805456
# [13]	validation_0-auc:0.802444
# [14]	validation_0-auc:0.805087
# [15]	validation_0-auc:0.807573
# [16]	validation_0-auc:0.809231
# [17]	validation_0-auc:0.810527
# [18]	validation_0-auc:0.811754
# [19]	validation_0-auc:0.814438
# [20]	validation_0-auc:0.814711
# [21]	validation_0-auc:0.815693
# [22]	validation_0-auc:0.816347
# [23]	validation_0-auc:0.816673
# [24]	validation_0-auc:0.816869
# [25]	validation_0-auc:0.817856
# [26]	validation_0-auc:0.818504
# [27]	validation_0-auc:0.818897
# [28]	validation_0-auc:0.819453
# [29]	validation_0-auc:0.819210
# [30]	validation_0-auc:0.819931
# [31]	validation_0-auc:0.821094
# [32]	validation_0-auc:0.821367
# [33]	validation_0-auc:0.820629
# [34]	validation_0-auc:0.821410
# [35]	validation_0-auc:0.820143
# [36]	validation_0-auc:0.819329
# [37]	validation_0-auc:0.820229
# [38]	validation_0-auc:0.819304
# [39]	validation_0-auc:0.820032
# [40]	validation_0-auc:0.821054
# [41]	validation_0-auc:0.822510
# [42]	validation_0-auc:0.821508
# [43]	validation_0-auc:0.822702
# [44]	validation_0-auc:0.823435
# [45]	validation_0-auc:0.824289
# [46]	validation_0-auc:0.825179
# [47]	validation_0-auc:0.825793
# [48]	validation_0-auc:0.824678
# [49]	validation_0-auc:0.825195
# [50]	validation_0-auc:0.824624
# [51]	validation_0-auc:0.824836
# [52]	validation_0-auc:0.825128
# [53]	validation_0-auc:0.826230
# [54]	validation_0-auc:0.827042
# [55]	validation_0-auc:0.827777
# [56]	validation_0-auc:0.827827
# [57]	validation_0-auc:0.828502
# [58]	validation_0-auc:0.829032
# [59]	validation_0-auc:0.829453
# [60]	validation_0-auc:0.828965
# [61]	validation_0-auc:0.829429
# [62]	validation_0-auc:0.829912
# [63]	validation_0-auc:0.829463
# [64]	validation_0-auc:0.829363
# [65]	validation_0-auc:0.830068
# [66]	validation_0-auc:0.830667
# [67]	validation_0-auc:0.831420
# [68]	validation_0-auc:0.832587
# [69]	validation_0-auc:0.833718
# [70]	validation_0-auc:0.832898
# [71]	validation_0-auc:0.834091
# [72]	validation_0-auc:0.834655
# [73]	validation_0-auc:0.835245
# [74]	validation_0-auc:0.835290
# [75]	validation_0-auc:0.835100
# [76]	validation_0-auc:0.835763
# [77]	validation_0-auc:0.836248
# [78]	validation_0-auc:0.836901
# [79]	validation_0-auc:0.837679
# [80]	validation_0-auc:0.838024
# [81]	validation_0-auc:0.838559
# [82]	validation_0-auc:0.839003
# [83]	validation_0-auc:0.839312
# [84]	validation_0-auc:0.839558
# [85]	validation_0-auc:0.839866
# [86]	validation_0-auc:0.840410
# [87]	validation_0-auc:0.840751
# [88]	validation_0-auc:0.841317
# [89]	validation_0-auc:0.841883
# [90]	validation_0-auc:0.842437
# [91]	validation_0-auc:0.843008
# [92]	validation_0-auc:0.842614
# [93]	validation_0-auc:0.843250
# [94]	validation_0-auc:0.843911
# [95]	validation_0-auc:0.844471
# [96]	validation_0-auc:0.845045
# [97]	validation_0-auc:0.845931
# [98]	validation_0-auc:0.846589
# [99]	validation_0-auc:0.846992
# [100]	validation_0-auc:0.847156
# [101]	validation_0-auc:0.847606
# [102]	validation_0-auc:0.848023
# [103]	validation_0-auc:0.848614
# [104]	validation_0-auc:0.849045
# [105]	validation_0-auc:0.849560
# [106]	validation_0-auc:0.850268
# [107]	validation_0-auc:0.850788
# [108]	validation_0-auc:0.851465
# [109]	validation_0-auc:0.851961
# [110]	validation_0-auc:0.852470
# [111]	validation_0-auc:0.853028
# [112]	validation_0-auc:0.853767
# [113]	validation_0-auc:0.854686
# [114]	validation_0-auc:0.854156
# [115]	validation_0-auc:0.854615
# [116]	validation_0-auc:0.854938
# [117]	validation_0-auc:0.855669
# [118]	validation_0-auc:0.855911
# [119]	validation_0-auc:0.856235
# [120]	validation_0-auc:0.856298
# [121]	validation_0-auc:0.856846
# [122]	validation_0-auc:0.857324
# [123]	validation_0-auc:0.857775
# [124]	validation_0-auc:0.858249
# [125]	validation_0-auc:0.858702
# [126]	validation_0-auc:0.859122
# [127]	validation_0-auc:0.859745
# [128]	validation_0-auc:0.860189
# [129]	validation_0-auc:0.860554
# [130]	validation_0-auc:0.860913
# [131]	validation_0-auc:0.861313
# [132]	validation_0-auc:0.861600
# [133]	validation_0-auc:0.862193
# [134]	validation_0-auc:0.862579
# [135]	validation_0-auc:0.862391
# [136]	validation_0-auc:0.862884
# [137]	validation_0-auc:0.863248
# [138]	validation_0-auc:0.863405
# [139]	validation_0-auc:0.863645
# [140]	validation_0-auc:0.864039
# [141]	validation_0-auc:0.864464
# [142]	validation_0-auc:0.865203
# [143]	validation_0-auc:0.864927
# [144]	validation_0-auc:0.865388
# [145]	validation_0-auc:0.865730
# [146]	validation_0-auc:0.866125
# [147]	validation_0-auc:0.866552
# [148]	validation_0-auc:0.867025
# [149]	validation_0-auc:0.867542
# [150]	validation_0-auc:0.867809
# [151]	validation_0-auc:0.867903
# [152]	validation_0-auc:0.868197
# [153]	validation_0-auc:0.868635
# [154]	validation_0-auc:0.868866
# [155]	validation_0-auc:0.869219
# [156]	validation_0-auc:0.869608
# [157]	validation_0-auc:0.870045
# [158]	validation_0-auc:0.870237
# [159]	validation_0-auc:0.870681
# [160]	validation_0-auc:0.871026
# [161]	validation_0-auc:0.871382
# [162]	validation_0-auc:0.871680
# [163]	validation_0-auc:0.872095
# [164]	validation_0-auc:0.872206
# [165]	validation_0-auc:0.872533
# [166]	validation_0-auc:0.872823
# [167]	validation_0-auc:0.873242
# [168]	validation_0-auc:0.873528
# [169]	validation_0-auc:0.873707
# [170]	validation_0-auc:0.874136
# [171]	validation_0-auc:0.874694
# [172]	validation_0-auc:0.874980
# [173]	validation_0-auc:0.875370
# [174]	validation_0-auc:0.875809
# [175]	validation_0-auc:0.876203
# [176]	validation_0-auc:0.876685
# [177]	validation_0-auc:0.877065
# [178]	validation_0-auc:0.877459
# [179]	validation_0-auc:0.877709
# [180]	validation_0-auc:0.877922
# [181]	validation_0-auc:0.878216
# [182]	validation_0-auc:0.877977
# [183]	validation_0-auc:0.878205
# [184]	validation_0-auc:0.878465
# [185]	validation_0-auc:0.878779
# [186]	validation_0-auc:0.878996
# [187]	validation_0-auc:0.879395
# [188]	validation_0-auc:0.879769
# [189]	validation_0-auc:0.880141
# [190]	validation_0-auc:0.880334
# [191]	validation_0-auc:0.880613
# [192]	validation_0-auc:0.880856
# [193]	validation_0-auc:0.881135
# [194]	validation_0-auc:0.881481
# [195]	validation_0-auc:0.881700
# [196]	validation_0-auc:0.882042
# [197]	validation_0-auc:0.882377
# [198]	validation_0-auc:0.882673
# [199]	validation_0-auc:0.882893
# [200]	validation_0-auc:0.883055
# [201]	validation_0-auc:0.883320
# [202]	validation_0-auc:0.883763
# [203]	validation_0-auc:0.884052
# [204]	validation_0-auc:0.884340
# [205]	validation_0-auc:0.884626
# [206]	validation_0-auc:0.884899
# [207]	validation_0-auc:0.885127
# [208]	validation_0-auc:0.885482
# [209]	validation_0-auc:0.885608
# [210]	validation_0-auc:0.885840
# [211]	validation_0-auc:0.886046
# [212]	validation_0-auc:0.886383
# [213]	validation_0-auc:0.886716
# [214]	validation_0-auc:0.886947
# [215]	validation_0-auc:0.887171
# [216]	validation_0-auc:0.887452
# [217]	validation_0-auc:0.887820
# [218]	validation_0-auc:0.888074
# [219]	validation_0-auc:0.888229
# [220]	validation_0-auc:0.888347
# [221]	validation_0-auc:0.888453
# [222]	validation_0-auc:0.888596
# [223]	validation_0-auc:0.888808
# [224]	validation_0-auc:0.888998
# [225]	validation_0-auc:0.889142
# [226]	validation_0-auc:0.889373
# [227]	validation_0-auc:0.889296
# [228]	validation_0-auc:0.889597
# [229]	validation_0-auc:0.889743
# [230]	validation_0-auc:0.889879
# [231]	validation_0-auc:0.890124
# [232]	validation_0-auc:0.890270
# [233]	validation_0-auc:0.890488
# [234]	validation_0-auc:0.890729
# [235]	validation_0-auc:0.890967
# [236]	validation_0-auc:0.891174
# [237]	validation_0-auc:0.891375
# [238]	validation_0-auc:0.891363
# [239]	validation_0-auc:0.891477
# [240]	validation_0-auc:0.891805
# [241]	validation_0-auc:0.891992
# [242]	validation_0-auc:0.892111
# [243]	validation_0-auc:0.892305
# [244]	validation_0-auc:0.892482
# [245]	validation_0-auc:0.892596
# [246]	validation_0-auc:0.892743
# [247]	validation_0-auc:0.892881
# [248]	validation_0-auc:0.893003
# [249]	validation_0-auc:0.893115
# [250]	validation_0-auc:0.893304
# [251]	validation_0-auc:0.893562
# [252]	validation_0-auc:0.893777
# [253]	validation_0-auc:0.893971
# [254]	validation_0-auc:0.894129
# [255]	validation_0-auc:0.894289
# [256]	validation_0-auc:0.894525
# [257]	validation_0-auc:0.894658
# [258]	validation_0-auc:0.894878
# [259]	validation_0-auc:0.895063
# [260]	validation_0-auc:0.895226
# [261]	validation_0-auc:0.895410
# [262]	validation_0-auc:0.895575
# [263]	validation_0-auc:0.895506
# [264]	validation_0-auc:0.895742
# [265]	validation_0-auc:0.895923
# [266]	validation_0-auc:0.896119
# [267]	validation_0-auc:0.896312
# [268]	validation_0-auc:0.896550
# [269]	validation_0-auc:0.896708
# [270]	validation_0-auc:0.896824
# [271]	validation_0-auc:0.897000
# [272]	validation_0-auc:0.897184
# [273]	validation_0-auc:0.897302
# [274]	validation_0-auc:0.897488
# [275]	validation_0-auc:0.897678
# [276]	validation_0-auc:0.897835
# [277]	validation_0-auc:0.898017
# [278]	validation_0-auc:0.898165
# [279]	validation_0-auc:0.898294
# [280]	validation_0-auc:0.898404
# [281]	validation_0-auc:0.898615
# [282]	validation_0-auc:0.898740
# [283]	validation_0-auc:0.898663
# [284]	validation_0-auc:0.898748
# [285]	validation_0-auc:0.898926
# [286]	validation_0-auc:0.899047
# [287]	validation_0-auc:0.899235
# [288]	validation_0-auc:0.899421
# [289]	validation_0-auc:0.899566
# [290]	validation_0-auc:0.899709
# [291]	validation_0-auc:0.899861
# [292]	validation_0-auc:0.900063

# %%
X_test = df_test[features].as_matrix()
t_pred=clf.predict_proba(X_test)[:,1]
plt.plot(t_pred)

id_test = df_test['ID']
submission = pd.DataFrame({"ID":id_test, "TARGET": t_pred})
submission.to_csv("./data/submission_xgb.csv", index=False)
