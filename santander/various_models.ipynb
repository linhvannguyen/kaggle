# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
from sklearn import linear_model, metrics, preprocessing
from sklearn.feature_selection import RFE,SelectPercentile,f_classif,chi2
from sklearn.metrics import roc_auc_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier 
from sklearn.feature_selection import SelectFromModel
import xgboost as xgb

# %% [markdown]
# ### Load data

# %%
df_train = pd.read_csv('./data/train.csv')
df_test = pd.read_csv('./data/test.csv')

# %% [markdown]
# ### Remove constant columns

# %%
remove = []
for col in df_train.columns:
    if df_train[col].std() == 0:
        remove.append(col)

df_train.drop(remove, axis=1, inplace=True)
df_test.drop(remove, axis=1, inplace=True)

# %% [markdown]
# ### Remove duplicated columns

# %%
remove = []
c = df_train.columns
for i in range(len(c)-1):
    v = df_train[c[i]].values
    for j in range(i+1,len(c)):
        if np.array_equal(v,df_train[c[j]].values):
            remove.append(c[j])

df_train.drop(remove, axis=1, inplace=True)
df_test.drop(remove, axis=1, inplace=True)

# %% [markdown]
# ### Other cleaning

# %%
# Replace -999999 in var3 column with most common value 2 
df_train = df_train.replace(-999999,2)
df_test = df_test.replace(-999999,2)

# %% [markdown]
# ### Feature selection

# %%
Xdf_tr = df_train.drop('TARGET', 1)
tdf_tr = df_train.TARGET

from sklearn.preprocessing import Binarizer, scale

p = 50 # percentage of selected features

X_bin = Binarizer().fit_transform(scale(Xdf_tr))
selectChi2 = SelectPercentile(chi2, percentile=p).fit(X_bin, tdf_tr)
selectF_classif = SelectPercentile(f_classif, percentile=p).fit(Xdf_tr, tdf_tr)

chi2_selected = selectChi2.get_support()
chi2_selected_features = [ f for i,f in enumerate(Xdf_tr.columns) if chi2_selected[i]]

f_classif_selected = selectF_classif.get_support()
f_classif_selected_features = [ f for i,f in enumerate(Xdf_tr.columns) if f_classif_selected[i]]


selected = chi2_selected | f_classif_selected
print('Chi2 & F_classif selected {} features'.format(selected.sum()))
features = [ f for f,s in zip(Xdf_tr.columns, selected) if s]

# print('List of features:{}'.format(features))
Xdf=df_train[features]
# Out:
# Chi2 & F_classif selected 173 features
# /home/nguyen/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.py:167: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "

# %% [markdown]
# ### Extract training data

# %%
X_tr = Xdf.as_matrix()
t_tr = df_train['TARGET'].as_matrix()

# Split up the data
X_fit, X_eval, t_fit, t_eval = train_test_split(X_tr, t_tr, test_size=0.25, random_state=42)

N_tr=np.shape(X_tr)[0]
D=np.shape(X_tr)[1]

# %%
# classifier
# http://xgboost.readthedocs.org/en/latest/parameter.html
# http://xgboost.readthedocs.org/en/latest/param_tuning.html
clf = xgb.XGBClassifier(
      objective= 'binary:logistic',    
      learning_rate=0.016, 
      n_estimators=750,
      max_depth=7,
      subsample=0.85,
      colsample_bytree=0.85,
      nthread=4,
      silent = 1,
      seed=8
)
# best observed: learning_rate=0.0175, n_estimators=400,max_depth=8,subsample=0.9,colsample_bytree=0.87,  seed=8
#clf = xgb.XGBClassifier(missing=np.nan, objective='binary:logistic', max_depth=8, n_estimators=170, 
#                        learning_rate=0.02, nthread=4, subsample=0.90, colsample_bytree=0.87,seed=8)

X_fit, X_eval, t_fit, t_eval= train_test_split(X_tr, t_tr, test_size=0.25,random_state=42)

# fitting
clf.fit(X_fit, t_fit, early_stopping_rounds=50, eval_metric="auc", eval_set=[(X_eval, t_eval)])

# Predict training data
t_hat_fit = clf.predict_proba(X_fit)[:,1]

# Predict test data
t_hat_eval = clf.predict_proba(X_eval)[:,1]

# Print model report:
print("\nModel Report")
print("AUC Score (Train): %f" % roc_auc_score(t_fit, t_hat_fit))
print("AUC Score (Test) : %f" % roc_auc_score(t_eval,  t_hat_eval))
# Out:
# Will train until validation_0 error hasn't decreased in 50 rounds.
# [0]	validation_0-auc:0.702894
# [1]	validation_0-auc:0.770061
# [2]	validation_0-auc:0.776871
# [3]	validation_0-auc:0.777932
# [4]	validation_0-auc:0.775499
# [5]	validation_0-auc:0.779526
# [6]	validation_0-auc:0.781459
# [7]	validation_0-auc:0.780998
# [8]	validation_0-auc:0.775243
# [9]	validation_0-auc:0.776539
# [10]	validation_0-auc:0.776979
# [11]	validation_0-auc:0.774763
# [12]	validation_0-auc:0.775939
# [13]	validation_0-auc:0.775253
# [14]	validation_0-auc:0.773602
# [15]	validation_0-auc:0.774552
# [16]	validation_0-auc:0.775465
# [17]	validation_0-auc:0.773506
# [18]	validation_0-auc:0.774163
# [19]	validation_0-auc:0.774991
# [20]	validation_0-auc:0.775857
# [21]	validation_0-auc:0.774422
# [22]	validation_0-auc:0.775031
# [23]	validation_0-auc:0.775771
# [24]	validation_0-auc:0.776211
# [25]	validation_0-auc:0.776452
# [26]	validation_0-auc:0.776125
# [27]	validation_0-auc:0.775660
# [28]	validation_0-auc:0.775399
# [29]	validation_0-auc:0.776236
# [30]	validation_0-auc:0.776678
# [31]	validation_0-auc:0.777797
# [32]	validation_0-auc:0.778239
# [33]	validation_0-auc:0.778899
# [34]	validation_0-auc:0.779428
# [35]	validation_0-auc:0.778912
# [36]	validation_0-auc:0.779771
# [37]	validation_0-auc:0.780306
# [38]	validation_0-auc:0.781252
# [39]	validation_0-auc:0.781730
# [40]	validation_0-auc:0.782235
# [41]	validation_0-auc:0.781829
# [42]	validation_0-auc:0.782452
# [43]	validation_0-auc:0.782800
# [44]	validation_0-auc:0.782605
# [45]	validation_0-auc:0.783492
# [46]	validation_0-auc:0.784152
# [47]	validation_0-auc:0.784420
# [48]	validation_0-auc:0.785146
# [49]	validation_0-auc:0.785563
# [50]	validation_0-auc:0.785780
# [51]	validation_0-auc:0.785409
# [52]	validation_0-auc:0.785899
# [53]	validation_0-auc:0.786385
# [54]	validation_0-auc:0.786885
# [55]	validation_0-auc:0.787392
# [56]	validation_0-auc:0.787927
# [57]	validation_0-auc:0.788181
# [58]	validation_0-auc:0.788713
# [59]	validation_0-auc:0.789142
# [60]	validation_0-auc:0.789602
# [61]	validation_0-auc:0.790003
# [62]	validation_0-auc:0.789286
# [63]	validation_0-auc:0.788935
# [64]	validation_0-auc:0.789667
# [65]	validation_0-auc:0.789374
# [66]	validation_0-auc:0.790669
# [67]	validation_0-auc:0.790988
# [68]	validation_0-auc:0.791381
# [69]	validation_0-auc:0.791775
# [70]	validation_0-auc:0.792478
# [71]	validation_0-auc:0.792322
# [72]	validation_0-auc:0.792639
# [73]	validation_0-auc:0.792522
# [74]	validation_0-auc:0.792719
# [75]	validation_0-auc:0.793331
# [76]	validation_0-auc:0.792917
# [77]	validation_0-auc:0.793289
# [78]	validation_0-auc:0.793759
# [79]	validation_0-auc:0.794163
# [80]	validation_0-auc:0.794494
# [81]	validation_0-auc:0.794966
# [82]	validation_0-auc:0.794564
# [83]	validation_0-auc:0.794906
# [84]	validation_0-auc:0.795311
# [85]	validation_0-auc:0.795773
# [86]	validation_0-auc:0.796214
# [87]	validation_0-auc:0.796804
# [88]	validation_0-auc:0.797306
# [89]	validation_0-auc:0.797793
# [90]	validation_0-auc:0.798168
# [91]	validation_0-auc:0.798640
# [92]	validation_0-auc:0.798942
# [93]	validation_0-auc:0.799236
# [94]	validation_0-auc:0.799460
# [95]	validation_0-auc:0.799768
# [96]	validation_0-auc:0.800173
# [97]	validation_0-auc:0.800490
# [98]	validation_0-auc:0.800809
# [99]	validation_0-auc:0.800684
# [100]	validation_0-auc:0.800950
# [101]	validation_0-auc:0.801462
# [102]	validation_0-auc:0.801760
# [103]	validation_0-auc:0.801964
# [104]	validation_0-auc:0.802315
# [105]	validation_0-auc:0.802728
# [106]	validation_0-auc:0.803116
# [107]	validation_0-auc:0.803454
# [108]	validation_0-auc:0.803723
# [109]	validation_0-auc:0.804088
# [110]	validation_0-auc:0.804553
# [111]	validation_0-auc:0.804622
# [112]	validation_0-auc:0.804943
# [113]	validation_0-auc:0.805346
# [114]	validation_0-auc:0.805611
# [115]	validation_0-auc:0.805905
# [116]	validation_0-auc:0.806425
# [117]	validation_0-auc:0.806660
# [118]	validation_0-auc:0.807015
# [119]	validation_0-auc:0.807201
# [120]	validation_0-auc:0.807441
# [121]	validation_0-auc:0.807837
# [122]	validation_0-auc:0.807846
# [123]	validation_0-auc:0.808143
# [124]	validation_0-auc:0.808466
# [125]	validation_0-auc:0.809003
# [126]	validation_0-auc:0.809481
# [127]	validation_0-auc:0.809924
# [128]	validation_0-auc:0.810326
# [129]	validation_0-auc:0.810757
# [130]	validation_0-auc:0.811021
# [131]	validation_0-auc:0.811426
# [132]	validation_0-auc:0.811886
# [133]	validation_0-auc:0.811908
# [134]	validation_0-auc:0.812242
# [135]	validation_0-auc:0.812675
# [136]	validation_0-auc:0.813078
# [137]	validation_0-auc:0.813473
# [138]	validation_0-auc:0.813825
# [139]	validation_0-auc:0.814130
# [140]	validation_0-auc:0.814471
# [141]	validation_0-auc:0.814815
# [142]	validation_0-auc:0.815104
# [143]	validation_0-auc:0.815425
# [144]	validation_0-auc:0.815820
# [145]	validation_0-auc:0.816129
# [146]	validation_0-auc:0.816361
# [147]	validation_0-auc:0.816737
# [148]	validation_0-auc:0.817123
# [149]	validation_0-auc:0.817384
# [150]	validation_0-auc:0.817136
# [151]	validation_0-auc:0.817296
# [152]	validation_0-auc:0.817610
# [153]	validation_0-auc:0.817902
# [154]	validation_0-auc:0.817851
# [155]	validation_0-auc:0.817767
# [156]	validation_0-auc:0.817579
# [157]	validation_0-auc:0.817733
# [158]	validation_0-auc:0.817987
# [159]	validation_0-auc:0.818223
# [160]	validation_0-auc:0.818489
# [161]	validation_0-auc:0.818703
# [162]	validation_0-auc:0.819109
# [163]	validation_0-auc:0.819253
# [164]	validation_0-auc:0.819272
# [165]	validation_0-auc:0.819552
# [166]	validation_0-auc:0.819718
# [167]	validation_0-auc:0.819924
# [168]	validation_0-auc:0.820098
# [169]	validation_0-auc:0.820248
# [170]	validation_0-auc:0.820386
# [171]	validation_0-auc:0.820608
# [172]	validation_0-auc:0.820712
# [173]	validation_0-auc:0.820959
# [174]	validation_0-auc:0.821150
# [175]	validation_0-auc:0.821180
# [176]	validation_0-auc:0.821425
# [177]	validation_0-auc:0.821566
# [178]	validation_0-auc:0.821721
# [179]	validation_0-auc:0.821999
# [180]	validation_0-auc:0.822218
# [181]	validation_0-auc:0.822466
# [182]	validation_0-auc:0.822662
# [183]	validation_0-auc:0.822779
# [184]	validation_0-auc:0.823071
# [185]	validation_0-auc:0.823264
# [186]	validation_0-auc:0.823641
# [187]	validation_0-auc:0.823859
# [188]	validation_0-auc:0.823814
# [189]	validation_0-auc:0.824134
# [190]	validation_0-auc:0.824330
# [191]	validation_0-auc:0.824436
# [192]	validation_0-auc:0.824753
# [193]	validation_0-auc:0.824946
# [194]	validation_0-auc:0.825126
# [195]	validation_0-auc:0.825232
# [196]	validation_0-auc:0.825441
# [197]	validation_0-auc:0.825618
# [198]	validation_0-auc:0.825798
# [199]	validation_0-auc:0.825367
# [200]	validation_0-auc:0.825533
# [201]	validation_0-auc:0.825558
# [202]	validation_0-auc:0.825711
# [203]	validation_0-auc:0.825797
# [204]	validation_0-auc:0.825862
# [205]	validation_0-auc:0.825941
# [206]	validation_0-auc:0.826108
# [207]	validation_0-auc:0.826218
# [208]	validation_0-auc:0.826116
# [209]	validation_0-auc:0.826262
# [210]	validation_0-auc:0.826305
# [211]	validation_0-auc:0.826404
# [212]	validation_0-auc:0.826563
# [213]	validation_0-auc:0.826553
# [214]	validation_0-auc:0.826555
# [215]	validation_0-auc:0.826628
# [216]	validation_0-auc:0.826722
# [217]	validation_0-auc:0.826936
# [218]	validation_0-auc:0.827080
# [219]	validation_0-auc:0.827197
# [220]	validation_0-auc:0.827259
# [221]	validation_0-auc:0.827230
# [222]	validation_0-auc:0.827273
# [223]	validation_0-auc:0.827373
# [224]	validation_0-auc:0.827510
# [225]	validation_0-auc:0.827497
# [226]	validation_0-auc:0.827514
# [227]	validation_0-auc:0.827594
# [228]	validation_0-auc:0.827508
# [229]	validation_0-auc:0.827555
# [230]	validation_0-auc:0.827641
# [231]	validation_0-auc:0.827828
# [232]	validation_0-auc:0.827866
# [233]	validation_0-auc:0.827926
# [234]	validation_0-auc:0.827992
# [235]	validation_0-auc:0.827990
# [236]	validation_0-auc:0.828076
# [237]	validation_0-auc:0.828119
# [238]	validation_0-auc:0.828253
# [239]	validation_0-auc:0.828285
# [240]	validation_0-auc:0.828120
# [241]	validation_0-auc:0.828086
# [242]	validation_0-auc:0.828098
# [243]	validation_0-auc:0.828153
# [244]	validation_0-auc:0.828121
# [245]	validation_0-auc:0.828244
# [246]	validation_0-auc:0.828328
# [247]	validation_0-auc:0.828442
# [248]	validation_0-auc:0.828418
# [249]	validation_0-auc:0.828437
# [250]	validation_0-auc:0.828534
# [251]	validation_0-auc:0.828587
# [252]	validation_0-auc:0.828500
# [253]	validation_0-auc:0.828586
# [254]	validation_0-auc:0.828680
# [255]	validation_0-auc:0.828695
# [256]	validation_0-auc:0.828733
# [257]	validation_0-auc:0.828774
# [258]	validation_0-auc:0.828817
# [259]	validation_0-auc:0.828879
# [260]	validation_0-auc:0.829021
# [261]	validation_0-auc:0.829166
# [262]	validation_0-auc:0.829258
# [263]	validation_0-auc:0.829337
# [264]	validation_0-auc:0.829385
# [265]	validation_0-auc:0.829342
# [266]	validation_0-auc:0.829395
# [267]	validation_0-auc:0.829456
# [268]	validation_0-auc:0.829502
# [269]	validation_0-auc:0.829521
# [270]	validation_0-auc:0.829441
# [271]	validation_0-auc:0.829515
# [272]	validation_0-auc:0.829576
# [273]	validation_0-auc:0.829555
# [274]	validation_0-auc:0.829587
# [275]	validation_0-auc:0.829653
# [276]	validation_0-auc:0.829662
# [277]	validation_0-auc:0.829719
# [278]	validation_0-auc:0.829699
# [279]	validation_0-auc:0.829750
# [280]	validation_0-auc:0.829699
# [281]	validation_0-auc:0.829783
# [282]	validation_0-auc:0.829882
# [283]	validation_0-auc:0.829928
# [284]	validation_0-auc:0.830005
# [285]	validation_0-auc:0.830007
# [286]	validation_0-auc:0.829985
# [287]	validation_0-auc:0.830041
# [288]	validation_0-auc:0.830143
# [289]	validation_0-auc:0.830175
# [290]	validation_0-auc:0.830212
# [291]	validation_0-auc:0.830200
# [292]	validation_0-auc:0.830281
# [293]	validation_0-auc:0.830267
# [294]	validation_0-auc:0.830310
# [295]	validation_0-auc:0.830334
# [296]	validation_0-auc:0.830346
# [297]	validation_0-auc:0.830309
# [298]	validation_0-auc:0.830362
# [299]	validation_0-auc:0.830357
# [300]	validation_0-auc:0.830372
# [301]	validation_0-auc:0.830427
# [302]	validation_0-auc:0.830464
# [303]	validation_0-auc:0.830505
# [304]	validation_0-auc:0.830435
# [305]	validation_0-auc:0.830475
# [306]	validation_0-auc:0.830536
# [307]	validation_0-auc:0.830534
# [308]	validation_0-auc:0.830615
# [309]	validation_0-auc:0.830611
# [310]	validation_0-auc:0.830537
# [311]	validation_0-auc:0.830508
# [312]	validation_0-auc:0.830597
# [313]	validation_0-auc:0.830690
# [314]	validation_0-auc:0.830791
# [315]	validation_0-auc:0.830850
# [316]	validation_0-auc:0.830825
# [317]	validation_0-auc:0.830898
# [318]	validation_0-auc:0.830935
# [319]	validation_0-auc:0.830943
# [320]	validation_0-auc:0.831022
# [321]	validation_0-auc:0.831050
# [322]	validation_0-auc:0.831139
# [323]	validation_0-auc:0.831124
# [324]	validation_0-auc:0.831105
# [325]	validation_0-auc:0.831189
# [326]	validation_0-auc:0.831249
# [327]	validation_0-auc:0.831217
# [328]	validation_0-auc:0.831227
# [329]	validation_0-auc:0.831276
# [330]	validation_0-auc:0.831289
# [331]	validation_0-auc:0.831268
# [332]	validation_0-auc:0.831354
# [333]	validation_0-auc:0.831376
# [334]	validation_0-auc:0.831401
# [335]	validation_0-auc:0.831391
# [336]	validation_0-auc:0.831445
# [337]	validation_0-auc:0.831497
# [338]	validation_0-auc:0.831564
# [339]	validation_0-auc:0.831608
# [340]	validation_0-auc:0.831621
# [341]	validation_0-auc:0.831618
# [342]	validation_0-auc:0.831664
# [343]	validation_0-auc:0.831669
# [344]	validation_0-auc:0.831709
# [345]	validation_0-auc:0.831732
# [346]	validation_0-auc:0.831761
# [347]	validation_0-auc:0.831843
# [348]	validation_0-auc:0.831840
# [349]	validation_0-auc:0.831784
# [350]	validation_0-auc:0.831804
# [351]	validation_0-auc:0.831794
# [352]	validation_0-auc:0.831831
# [353]	validation_0-auc:0.831767
# [354]	validation_0-auc:0.831804
# [355]	validation_0-auc:0.831790
# [356]	validation_0-auc:0.831829
# [357]	validation_0-auc:0.831832
# [358]	validation_0-auc:0.831868
# [359]	validation_0-auc:0.831863
# [360]	validation_0-auc:0.831917
# [361]	validation_0-auc:0.831899
# [362]	validation_0-auc:0.831922
# [363]	validation_0-auc:0.831945
# [364]	validation_0-auc:0.831924
# [365]	validation_0-auc:0.831918
# [366]	validation_0-auc:0.831936
# [367]	validation_0-auc:0.831906
# [368]	validation_0-auc:0.831921
# [369]	validation_0-auc:0.831924
# [370]	validation_0-auc:0.831946
# [371]	validation_0-auc:0.831968
# [372]	validation_0-auc:0.832034
# [373]	validation_0-auc:0.832045
# [374]	validation_0-auc:0.832071
# [375]	validation_0-auc:0.832130
# [376]	validation_0-auc:0.832157
# [377]	validation_0-auc:0.832001
# [378]	validation_0-auc:0.831995
# [379]	validation_0-auc:0.831971
# [380]	validation_0-auc:0.832018
# [381]	validation_0-auc:0.832034
# [382]	validation_0-auc:0.832095
# [383]	validation_0-auc:0.832021
# [384]	validation_0-auc:0.831988
# [385]	validation_0-auc:0.832046
# [386]	validation_0-auc:0.832016
# [387]	validation_0-auc:0.832097
# [388]	validation_0-auc:0.832154
# [389]	validation_0-auc:0.832208
# [390]	validation_0-auc:0.832198
# [391]	validation_0-auc:0.832154
# [392]	validation_0-auc:0.832146
# [393]	validation_0-auc:0.832176
# [394]	validation_0-auc:0.832166
# [395]	validation_0-auc:0.832185
# [396]	validation_0-auc:0.832148
# [397]	validation_0-auc:0.832196
# [398]	validation_0-auc:0.832188
# [399]	validation_0-auc:0.832198
# [400]	validation_0-auc:0.832161
# [401]	validation_0-auc:0.832190
# [402]	validation_0-auc:0.832219
# [403]	validation_0-auc:0.832250
# [404]	validation_0-auc:0.832261
# [405]	validation_0-auc:0.832230
# [406]	validation_0-auc:0.832232
# [407]	validation_0-auc:0.832224
# [408]	validation_0-auc:0.832259
# [409]	validation_0-auc:0.832316
# [410]	validation_0-auc:0.832355
# [411]	validation_0-auc:0.832356
# [412]	validation_0-auc:0.832341
# [413]	validation_0-auc:0.832344
# [414]	validation_0-auc:0.832346
# [415]	validation_0-auc:0.832330
# [416]	validation_0-auc:0.832327
# [417]	validation_0-auc:0.832293
# [418]	validation_0-auc:0.832285
# [419]	validation_0-auc:0.832201
# [420]	validation_0-auc:0.832225
# [421]	validation_0-auc:0.832269
# [422]	validation_0-auc:0.832224
# [423]	validation_0-auc:0.832238
# [424]	validation_0-auc:0.832256
# [425]	validation_0-auc:0.832268
# [426]	validation_0-auc:0.832238
# [427]	validation_0-auc:0.832248
# [428]	validation_0-auc:0.832170
# [429]	validation_0-auc:0.832207
# [430]	validation_0-auc:0.832206
# [431]	validation_0-auc:0.832192
# [432]	validation_0-auc:0.832142
# [433]	validation_0-auc:0.832129
# [434]	validation_0-auc:0.832107
# [435]	validation_0-auc:0.832117
# [436]	validation_0-auc:0.832140
# [437]	validation_0-auc:0.832145
# [438]	validation_0-auc:0.832211
# [439]	validation_0-auc:0.832236
# [440]	validation_0-auc:0.832228
# [441]	validation_0-auc:0.832229
# [442]	validation_0-auc:0.832245
# [443]	validation_0-auc:0.832303
# [444]	validation_0-auc:0.832290
# [445]	validation_0-auc:0.832323
# [446]	validation_0-auc:0.832320
# [447]	validation_0-auc:0.832291
# [448]	validation_0-auc:0.832308
# [449]	validation_0-auc:0.832280
# [450]	validation_0-auc:0.832260
# [451]	validation_0-auc:0.832159
# [452]	validation_0-auc:0.832160
# [453]	validation_0-auc:0.832168
# [454]	validation_0-auc:0.832183
# [455]	validation_0-auc:0.832255
# [456]	validation_0-auc:0.832228
# [457]	validation_0-auc:0.832135
# [458]	validation_0-auc:0.832131
# [459]	validation_0-auc:0.832153
# [460]	validation_0-auc:0.832209
# Model Report
# AUC Score (Train): 0.913923
# AUC Score (Test) : 0.836837
# [461]	validation_0-auc:0.832195
# Stopping. Best iteration:
# [411]	validation_0-auc:0.832356

# %%
clf.fit(X_tr, t_tr, early_stopping_rounds=50, eval_metric="auc", eval_set=[(X_eval, t_eval)])
X_test = df_test[features].as_matrix()
t_pred=clf.predict_proba(X_test)[:,1]
plt.plot(t_pred)

# %%
id_test = df_test['ID']
submission = pd.DataFrame({"ID":id_test, "TARGET": t_pred})
submission.to_csv("./data/submission.csv", index=False)
